# %%
import requests

prompt = """
News:
Reliance gains after strong earnings.
Banking stocks rally.

Is market bullish or bearish?
"""

response = requests.post(
    "http://localhost:11434/api/generate",
    json={
        "model": "phi3",
        "prompt": prompt,
        "stream": False
    }
)

print(response.json()["response"])
# Out:
# The provided headlines suggest a positive outlook on the financial markets, particularly in relation to banking sector performance and reliance's (likely Reliance Industries) strong earnings report:
#
# 1. "Reliance gains after strong earnings" - This indicates that Reliance companies are performing well financially as reflected by their stock prices going up following the release of financial results indicating high profits or revenue growth, which is a bullish sign for investors and typically correlates with an overall positive market sentiment.
#
# 2. "Banking stocks rally" - Banking sector specifically shows signs of improvement as bank share values are increasing, often due to optimism about future profitability prospects or financial stability within the industry itself; this is another bullish indicator and suggests that investors might be gaining confidence in banks' performance.
#
# Considering these two headlines alone without additional context such as economic indicators (e.g., interest rates, inflation), broader market indices (like Sensex or Nifty trends) at the time of reading them, and external factors influencing markets worldwide would make it difficult to accurately state whether these indicate a bullish or bearish market overall.
#
# However, based solely on this specific information related to two strong performers in different sectors (technology/consumer goods with Reliance Industries and banking sector), one might infer that the sentiment is leaning towards being more 'bullish.' Investors appear optimistic about these companies' recent performances as it reflects broader market confidence. But without comprehensive analysis, this cannot be taken as an absolute representation of overall market condition.

# %%
import duckdb
from pathlib import Path

# Notebook cwd is often `notebooks/` — use project root so you hit the same DB as `scripts/Get_instruments.py`.
_root = Path.cwd()
if _root.name == "notebooks":
    _root = _root.parent
db_path = _root / "market_data.duckdb"

con = duckdb.connect(str(db_path))

# If this errors, run from project root: `python scripts/Get_instruments.py` (creates + fills `index_constituents`).
df = con.execute("""
SELECT *
FROM index_constituents
WHERE index_name = 'NIFTY_50'
""").fetchdf()

print(df.head())
con.close()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[3], line 5
#       1 import duckdb
#       2
#       3 con = duckdb.connect("market_data.duckdb")
#       4
# ----> 5 df = con.execute("""
#       6 SELECT *
#       7 FROM index_constituents
#       8 WHERE index_name = 'NIFTY_50'
#
# CatalogException: Catalog Error: Table with name index_constituents does not exist!
# Did you mean "pg_description"?
#
# LINE 3: FROM index_constituents
#              ^
